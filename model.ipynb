# %%
import json
import string
import random 
import nltk
import numpy as num
from nltk.stem import WordNetLemmatizer 
import tensorflow as tensorF
from tensorflow.keras import Sequential 
from tensorflow.keras.layers import Dense, Dropout
nltk.download("punkt")
nltk.download("wordnet")
nltk.download('omw-1.4')
import datetime
from google.colab import drive
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
class DateTimeJSONEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, datetime.datetime):
            return obj.isoformat()
        else:
            return super(DateTimeJSONEncoder, self).default(obj)

date = DateTimeJSONEncoder().encode(str(datetime.datetime.now()))

# %%
bbcnews = "https://www.bbc.com"
nytnews = "https://www.nytimes.com"

popurlar_songs = "https://top40-charts.com/chart.php?cid=31"

# %%
data = {
    "intents": [

        {
            "tag": "google",
            "patterns": [
                "google",
                "search",
                "internet"
            ],
            "responses": [
                "Redirecting to Google..."
            ]
        },
        {
            "tag": "greeting",
            "patterns": [
                "Hi there",
                "How are you",
                "Is anyone there?",
                "Hey",
                "Hola",
                "Hello",
                "Good day",
                "greetings",
                "yo"
            ],
            "responses": [
                "Hello",
                "Good to see you again",
                "Hi there, how can I help?"
            ],
            "context": [
                ""
            ]
        },
        {
            "tag": "goodbye",
            "patterns": [
                "Bye",
                "See you later",
                "Goodbye",
                "Get lost",
                "Till next time",
                "bye bye",
                "Bye chatbot",
                "bye Jak"
            ],
            "responses": [
                "See you!",
                "Have a nice day",
                "Bye! Come back again soon."
            ],
            "context": [
                ""
            ]
        },
        {
            "tag": "thanks",
            "patterns": [
                "Thanks",
                "Thank you",
                "That's helpful",
                "Awesome, thanks",
                "Thanks for helping me",
                "Thank you for helping me"
                "Thats great, thank you"
            ],
            "responses": [
                "Happy to help!",
                "Any time!",
                "My pleasure"
            ],
            "context": [
                ""
            ]
        },
        {
            "tag": "noanswer",
            "patterns": [],
            "responses": [
                "Sorry, can't understand you",
                "Please give me more info",
                "Not sure I understand"
            ],
            "context": [
                ""
            ]
        },
        {
            "tag": "options",
            "patterns": [
                "How you could help me?",
                "What you can do?",
                "What help you provide?",
                "How you can be helpful?",
                "What support is offered"
            ],
            "responses": [
                "I am a general purpose chatbot."
            ],
            "context": [
                ""
            ]
        },
        
        {
            "tag": "jokes",
            "patterns": [
                "Tell me a joke",
                "Joke",
                "Make me laugh",
                "I need to get in good mood"
            ],
            "responses": [
                "Did you hear about the mathematician who’s afraid of negative numbers? He’ll stop at nothing to avoid them.",
                "While visiting a zoo, which animal does a computer like watching the most? It definitely has to be a RAM!",
                "Why was the PowerPoint presentation so desperate to cross the road? Because he badly wanted to go the other slide!",
                "There are only ten kinds of people in this world: those who know binary and those who don't.",
                "Two strings walk into a bar. One says: I'd like a beer please. 25s3z %- 9238435. The other string says: Sorry about my friend, he's not null-terminated.",
                "3 Database SQL walked into a NoSQL bar. A little while later they walked out. Because they couldn't find a table"
            ],
            "context": [
                "jokes"
            ]
        },
        {
            "tag": "Identity",
            "patterns": [
                "Who are you",
                "what are you",
                "Are you a chatbot?"
                "Are you a bot?",
                "what is your name?",

            ],
            "responses": [
                "I am a Deep-Learning chatbot"
            ]
        },
        {
            "tag": "datetime",
            "patterns": [
                "What is the time",
                "what is the date",
                "date",
                "time",
                "tell me the date",
                "day",
                "what day is is today",
                "What time is it?"
                "whats the time?"
            ],
            "responses": [
                date
            ]
        },
        {
            "tag": "whatsup",
            "patterns": [
                "Whats up",
                "Wazzup",
                "How are you",
                "sup","How you doing"
            ],
            "responses": [
                "All good..What about you?"
            ]
        },
        {
            "tag": "haha",
            "patterns": [
                "haha",
                "lol",
                "rofl",
                "lmao",
                "thats funny",
                "That is so funny"
            ],
            "responses": [
                "Glad I could make you laugh !"
            ]
        },
        {
            "tag": "programmer",
            "patterns": [
                "Who made you",
                "who designed you",
                "who programmed you",
                "who developed you?"
            ],
            "responses": [
                "I was made by somebody,"
            ]
        },
        {
            "tag": "activity",
            "patterns": [
                "what are you doing",
                "what are you upto",
            ],
            "responses": [
                "Talking to you, of course!"
            ]
        },
        {
            "tag": "exclaim",
            "patterns": [
                "Awesome",
                "Great",
                "I know",
                "ok",
                "yeah"
            ],
            "responses": [
                "Yeah!"
            ]
        },
        
        {
            "tag": "weather",
            "patterns": [
                "temperature",
                "weather",
                "how hot is it",
                "How cold is it",
                "How is the weather today"

            ],
            "responses": [
                "..."
            ]
        },
        {
            "tag": "appreciate",
            "patterns": [
                "You are awesome",
                "you are the best",
                "you are great",
                "you are good",
                "You are very good",
                "You are a smart bot",
                "You are fantastic"
            ],
            "responses": [
                "Thank you!"
            ]
        },
        {
            "tag": "nicetty",
            "patterns": [
                "it was nice talking to you",
                "good talk",
                "nice talking to you",
                "Thanks for taking time to talk to me"
            ],
            "responses": [
                "It was nice talking to you as well! Come back soon!"
            ]
        },
        {
            "tag": "no",
            "patterns": [
                "no",
                "nope"
            ],
            "responses": [
                "ok"
            ]
        },
        {
            "tag": "news",
            "patterns": [
                "news",
                "latest news",
                "bbc news",
                "world news",
                "news in the world",
                "any news suggestions",
                "suggestions for news reading"
            ],
            "responses": [
                bbcnews,
                nytnews
            ]
        },
        {
            "tag": "algorithm",
            "patterns": [
                "what is an algorithm?",
                "can you tell me what an algorithm is?",
                "I dont understand what an algorithm is."
            ],
            "responses": [
                "An algorithm is a list of rules to follow in order to complete a task or solve a problem. E.g. Binary Search Algorithm, Merge Sort Algorithm, Quicksort Algorithm, Kruskal's Algorithm, Floyd Warshall Algorithm and Dijkstra's Algorithm. "
            ]
        },
        {
            "tag": "Scapegoat tree",
            "patterns": [
                "What is the Amortized Run Time of a Scapegoat Tree?",
                "Amortized Run Time of a Scapegoat Tree",
                "Scapegoat Tree",
                "What is Scapegoat Tree"
            ],
            "responses": [
                "Scapegoat Trees have amortized run times of O(log n) for insertion and deletion \n and for a sequence of m insertions  and deletions the overall run time is O(m log m) for all the rebuild operations.\
                \n A scapegoat tree is a self-balancing binary search tree, invented by Arne Andersson[2] in 1989 and again by Igal Galperin and Ronald L. Rivest in 1993."
            ]
        },
        {
            "tag": "song",
            "patterns": [
                "top songs",
                "best songs",
                "hot songs",
                "top 40 songs",
                "pop",
                "best songs in the world"
            ],
            "responses": [
                "You should check out " + popurlar_songs + "for top 40 hits."
            ]
        },
        {
            "tag": "greetreply",
            "patterns": [
                "i am good",
                "I'm good",
                "i am fine",
                " i'm fine","good"
            ],
            "responses": [
                "Good to know!"
            ]
        },
        {
            "tag": "timer",
            "patterns": [
                "set a timer"
            ],
            "responses": [
                "..."
            ]
        },
        {
            "tag": "suggest",
            "patterns": [
                "you are useless",
                "useless",
                "suggest",
                "suggestions",
                "you are bad",
                "you are not very good"
            ],
            "responses": [
                "Please If you have a suggestion to improve this, please fork the repo and create a pull request. You can also open an issue with the tag 'improvement'. Thank you for helping me improve!"
            ]
        },
        {
            "tag": "age",
            "patterns": [
                "how old are you","when were you made","what is your age"
            ],
            "responses": [
                "I was made in 2022, if that's what you are asking!"
            ]
        }
    ]
}

# %%
lemmatizer = WordNetLemmatizer()
data_classes = []
words = []
x = []
y = []
for i in data["intents"]:
  for j in i["patterns"]:
    tokens = nltk.word_tokenize(j)
    words.extend(tokens)
    x.append(j)
    y.append(i["tag"])
  
  if i["tag"] not in data_classes:
    data_classes.append(i["tag"])

words = [lemmatizer.lemmatize(word.lower()) for word in words if word not in string.punctuation]
words = sorted(set(words))
data_classes = sorted(set(data_classes))

# %%
training_data = []
output = [0] * len(data_classes)
for i,j in enumerate(x):
  bag_of_words = []
  text = lemmatizer.lemmatize(j.lower())
  for word in words:
    bag_of_words.append(1) if word in text else bag_of_words.append(0)
  
  output_row = list(output)
  output_row[data_classes.index(y[i])] = 1
  training_data.append([bag_of_words, output_row])

random.shuffle(training_data)
training_data = num.array(training_data, dtype=object)

xp = num.array(list(training_data[:, 0]))
yp = num.array(list(training_data[:, 1]))

# %%
shape_x = (len(xp[0]),)
shape_y = len(yp[0])

model = Sequential()
model.add(Dense(256, input_shape = shape_x, activation = "relu"))
model.add(Dropout(0.5))
model.add(Dense(128, activation = "relu"))
model.add(Dropout(0.3))
model.add(Dense(shape_y, activation = "softmax"))
op = tensorF.keras.optimizers.Adam(learning_rate = 0.001, decay =  1e-6)
model.compile(loss='categorical_crossentropy', 
              optimizer=op, 
              metrics=['accuracy'])
print(model.summary())
model.fit(xp, yp, epochs=200, verbose=1)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 256)               35584
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 128)               32896
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 28)                3612
#
# =================================================================
# Total params: 72,092
# Trainable params: 72,092
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/200
# 4/4 [==============================] - 0s 4ms/step - loss: 3.3254 - accuracy: 0.0480
# Epoch 2/200
# 4/4 [==============================] - 0s 3ms/step - loss: 3.2848 - accuracy: 0.0880
# Epoch 3/200
# 4/4 [==============================] - 0s 4ms/step - loss: 3.2316 - accuracy: 0.0800
# Epoch 4/200
# 4/4 [==============================] - 0s 5ms/step - loss: 3.1849 - accuracy: 0.1280
# Epoch 5/200
# 4/4 [==============================] - 0s 5ms/step - loss: 3.1205 - accuracy: 0.1920
# Epoch 6/200
# 4/4 [==============================] - 0s 4ms/step - loss: 3.0688 - accuracy: 0.2320
# Epoch 7/200
# 4/4 [==============================] - 0s 3ms/step - loss: 3.0226 - accuracy: 0.2960
# Epoch 8/200
# 4/4 [==============================] - 0s 3ms/step - loss: 2.9494 - accuracy: 0.2960
# Epoch 9/200
# 4/4 [==============================] - 0s 3ms/step - loss: 2.8777 - accuracy: 0.3440
# Epoch 10/200
# 4/4 [==============================] - 0s 3ms/step - loss: 2.8194 - accuracy: 0.3600
# Epoch 11/200
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6983 - accuracy: 0.4400
# Epoch 12/200
# 4/4 [==============================] - 0s 3ms/step - loss: 2.6510 - accuracy: 0.4240
# Epoch 13/200
# 4/4 [==============================] - 0s 3ms/step - loss: 2.5801 - accuracy: 0.4240
# Epoch 14/200
# 4/4 [==============================] - 0s 3ms/step - loss: 2.4474 - accuracy: 0.4240
# Epoch 15/200
# 4/4 [==============================] - 0s 3ms/step - loss: 2.3649 - accuracy: 0.5200
# Epoch 16/200
# 4/4 [==============================] - 0s 3ms/step - loss: 2.2720 - accuracy: 0.5120
# Epoch 17/200
# 4/4 [==============================] - 0s 3ms/step - loss: 2.1523 - accuracy: 0.5600
# Epoch 18/200
# 4/4 [==============================] - 0s 3ms/step - loss: 2.0598 - accuracy: 0.6160
# Epoch 19/200
# 4/4 [==============================] - 0s 4ms/step - loss: 1.9908 - accuracy: 0.6080
# Epoch 20/200
# 4/4 [==============================] - 0s 3ms/step - loss: 1.8672 - accuracy: 0.6160
# Epoch 21/200
# 4/4 [==============================] - 0s 3ms/step - loss: 1.7675 - accuracy: 0.7040
# Epoch 22/200
# 4/4 [==============================] - 0s 3ms/step - loss: 1.6211 - accuracy: 0.6560
# Epoch 23/200
# 4/4 [==============================] - 0s 5ms/step - loss: 1.6220 - accuracy: 0.6480
# Epoch 24/200
# 4/4 [==============================] - 0s 4ms/step - loss: 1.5460 - accuracy: 0.6720
# Epoch 25/200
# 4/4 [==============================] - 0s 3ms/step - loss: 1.4180 - accuracy: 0.6880
# Epoch 26/200
# 4/4 [==============================] - 0s 4ms/step - loss: 1.3332 - accuracy: 0.7120
# Epoch 27/200
# 4/4 [==============================] - 0s 6ms/step - loss: 1.3249 - accuracy: 0.7200
# Epoch 28/200
# 4/4 [==============================] - 0s 5ms/step - loss: 1.1547 - accuracy: 0.8080
# Epoch 29/200
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1755 - accuracy: 0.7280
# Epoch 30/200
# 4/4 [==============================] - 0s 4ms/step - loss: 1.0674 - accuracy: 0.8240
# Epoch 31/200
# 4/4 [==============================] - 0s 4ms/step - loss: 1.0509 - accuracy: 0.8080
# Epoch 32/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.9682 - accuracy: 0.8560
# Epoch 33/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9781 - accuracy: 0.8000
# Epoch 34/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9039 - accuracy: 0.8160
# Epoch 35/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8727 - accuracy: 0.8240
# Epoch 36/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7789 - accuracy: 0.8720
# Epoch 37/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7769 - accuracy: 0.8560
# Epoch 38/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7133 - accuracy: 0.8720
# Epoch 39/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6648 - accuracy: 0.9200
# Epoch 40/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6647 - accuracy: 0.8560
# Epoch 41/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6224 - accuracy: 0.9040
# Epoch 42/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5829 - accuracy: 0.9200
# Epoch 43/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5883 - accuracy: 0.8960
# Epoch 44/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5584 - accuracy: 0.9280
# Epoch 45/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4729 - accuracy: 0.9360
# Epoch 46/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4276 - accuracy: 0.9680
# Epoch 47/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4482 - accuracy: 0.9440
# Epoch 48/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4445 - accuracy: 0.9440
# Epoch 49/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4247 - accuracy: 0.9440
# Epoch 50/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4534 - accuracy: 0.9440
# Epoch 51/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3884 - accuracy: 0.9280
# Epoch 52/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3786 - accuracy: 0.9440
# Epoch 53/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4028 - accuracy: 0.9280
# Epoch 54/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3217 - accuracy: 0.9680
# Epoch 55/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3032 - accuracy: 0.9680
# Epoch 56/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3289 - accuracy: 0.9360
# Epoch 57/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2715 - accuracy: 0.9600
# Epoch 58/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2262 - accuracy: 0.9760
# Epoch 59/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2889 - accuracy: 0.9440
# Epoch 60/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2143 - accuracy: 0.9600
# Epoch 61/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2255 - accuracy: 0.9520
# Epoch 62/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2220 - accuracy: 0.9760
# Epoch 63/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2509 - accuracy: 0.9520
# Epoch 64/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2391 - accuracy: 0.9440
# Epoch 65/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2117 - accuracy: 0.9600
# Epoch 66/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2184 - accuracy: 0.9760
# Epoch 67/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2073 - accuracy: 0.9760
# Epoch 68/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2381 - accuracy: 0.9520
# Epoch 69/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1763 - accuracy: 0.9760
# Epoch 70/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2250 - accuracy: 0.9520
# Epoch 71/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1753 - accuracy: 0.9680
# Epoch 72/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1935 - accuracy: 0.9600
# Epoch 73/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1971 - accuracy: 0.9680
# Epoch 74/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1508 - accuracy: 0.9920
# Epoch 75/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1430 - accuracy: 0.9840
# Epoch 76/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1588 - accuracy: 0.9760
# Epoch 77/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1325 - accuracy: 0.9760
# Epoch 78/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1662 - accuracy: 0.9600
# Epoch 79/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1709 - accuracy: 0.9600
# Epoch 80/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1352 - accuracy: 0.9840
# Epoch 81/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1397 - accuracy: 0.9760
# Epoch 82/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1154 - accuracy: 0.9840
# Epoch 83/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1516 - accuracy: 0.9680
# Epoch 84/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1311 - accuracy: 0.9680
# Epoch 85/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1408 - accuracy: 0.9840
# Epoch 86/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1091 - accuracy: 0.9840
# Epoch 87/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1428 - accuracy: 0.9760
# Epoch 88/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1241 - accuracy: 0.9840
# Epoch 89/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1101 - accuracy: 0.9760
# Epoch 90/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1362 - accuracy: 0.9680
# Epoch 91/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1365 - accuracy: 0.9600
# Epoch 92/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0849 - accuracy: 0.9920
# Epoch 93/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1080 - accuracy: 0.9840
# Epoch 94/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1011 - accuracy: 0.9840
# Epoch 95/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1131 - accuracy: 0.9760
# Epoch 96/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1173 - accuracy: 0.9680
# Epoch 97/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0965 - accuracy: 0.9920
# Epoch 98/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0778 - accuracy: 0.9920
# Epoch 99/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1391 - accuracy: 0.9760
# Epoch 100/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0807 - accuracy: 0.9920
# Epoch 101/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0737 - accuracy: 1.0000
# Epoch 102/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1130 - accuracy: 0.9680
# Epoch 103/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0917 - accuracy: 0.9920
# Epoch 104/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0647 - accuracy: 1.0000
# Epoch 105/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0776 - accuracy: 0.9840
# Epoch 106/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1033 - accuracy: 0.9840
# Epoch 107/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0959 - accuracy: 0.9840
# Epoch 108/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1065 - accuracy: 0.9840
# Epoch 109/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0571 - accuracy: 1.0000
# Epoch 110/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0868 - accuracy: 0.9840
# Epoch 111/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0628 - accuracy: 0.9920
# Epoch 112/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0894 - accuracy: 0.9840
# Epoch 113/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0708 - accuracy: 0.9840
# Epoch 114/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0946 - accuracy: 0.9920
# Epoch 115/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0684 - accuracy: 1.0000
# Epoch 116/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0565 - accuracy: 1.0000
# Epoch 117/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0561 - accuracy: 0.9920
# Epoch 118/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0779 - accuracy: 0.9920
# Epoch 119/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0569 - accuracy: 0.9840
# Epoch 120/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0576 - accuracy: 0.9920
# Epoch 121/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0710 - accuracy: 0.9840
# Epoch 122/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0844 - accuracy: 0.9920
# Epoch 123/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0659 - accuracy: 0.9840
# Epoch 124/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0734 - accuracy: 0.9840
# Epoch 125/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0549 - accuracy: 0.9920
# Epoch 126/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0394 - accuracy: 1.0000
# Epoch 127/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0381 - accuracy: 1.0000
# Epoch 128/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0584 - accuracy: 0.9840
# Epoch 129/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0671 - accuracy: 0.9760
# Epoch 130/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0712 - accuracy: 0.9840
# Epoch 131/200
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0593 - accuracy: 0.9920
# Epoch 132/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0515 - accuracy: 0.9920
# Epoch 133/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0590 - accuracy: 0.9840
# Epoch 134/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0589 - accuracy: 0.9840
# Epoch 135/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0565 - accuracy: 0.9840
# Epoch 136/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0610 - accuracy: 0.9840
# Epoch 137/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0472 - accuracy: 0.9920
# Epoch 138/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0811 - accuracy: 0.9840
# Epoch 139/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0497 - accuracy: 0.9920
# Epoch 140/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0368 - accuracy: 0.9920
# Epoch 141/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0919 - accuracy: 0.9760
# Epoch 142/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0376 - accuracy: 0.9920
# Epoch 143/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0384 - accuracy: 1.0000
# Epoch 144/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0665 - accuracy: 0.9920
# Epoch 145/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0474 - accuracy: 0.9920
# Epoch 146/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0519 - accuracy: 0.9920
# Epoch 147/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0426 - accuracy: 0.9920
# Epoch 148/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0460 - accuracy: 0.9920
# Epoch 149/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0448 - accuracy: 0.9920
# Epoch 150/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0543 - accuracy: 0.9840
# Epoch 151/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0529 - accuracy: 0.9840
# Epoch 152/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0575 - accuracy: 0.9920
# Epoch 153/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0602 - accuracy: 0.9920
# Epoch 154/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0299 - accuracy: 1.0000
# Epoch 155/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0511 - accuracy: 0.9840
# Epoch 156/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0546 - accuracy: 0.9840
# Epoch 157/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0367 - accuracy: 1.0000
# Epoch 158/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0424 - accuracy: 0.9920
# Epoch 159/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0273 - accuracy: 1.0000
# Epoch 160/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0600 - accuracy: 0.9760
# Epoch 161/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0338 - accuracy: 0.9920
# Epoch 162/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0410 - accuracy: 1.0000
# Epoch 163/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0398 - accuracy: 0.9920
# Epoch 164/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0410 - accuracy: 0.9920
# Epoch 165/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0763 - accuracy: 0.9760
# Epoch 166/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0500 - accuracy: 0.9840
# Epoch 167/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0555 - accuracy: 0.9840
# Epoch 168/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0394 - accuracy: 0.9840
# Epoch 169/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0304 - accuracy: 0.9920
# Epoch 170/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0317 - accuracy: 0.9920
# Epoch 171/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0391 - accuracy: 0.9920
# Epoch 172/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0278 - accuracy: 0.9920
# Epoch 173/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0276 - accuracy: 1.0000
# Epoch 174/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0476 - accuracy: 0.9840
# Epoch 175/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0355 - accuracy: 1.0000
# Epoch 176/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0402 - accuracy: 0.9840
# Epoch 177/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0462 - accuracy: 0.9920
# Epoch 178/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0442 - accuracy: 0.9840
# Epoch 179/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0443 - accuracy: 0.9920
# Epoch 180/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0298 - accuracy: 0.9840
# Epoch 181/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0431 - accuracy: 0.9920
# Epoch 182/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0607 - accuracy: 0.9920
# Epoch 183/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0440 - accuracy: 0.9920
# Epoch 184/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0275 - accuracy: 1.0000
# Epoch 185/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0186 - accuracy: 1.0000
# Epoch 186/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0450 - accuracy: 0.9840
# Epoch 187/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0427 - accuracy: 0.9920
# Epoch 188/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0352 - accuracy: 1.0000
# Epoch 189/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0391 - accuracy: 0.9840
# Epoch 190/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0408 - accuracy: 0.9920
# Epoch 191/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0504 - accuracy: 0.9840
# Epoch 192/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0538 - accuracy: 0.9840
# Epoch 193/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0396 - accuracy: 0.9920
# Epoch 194/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0368 - accuracy: 0.9920
# Epoch 195/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0245 - accuracy: 0.9920
# Epoch 196/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0426 - accuracy: 0.9920
# Epoch 197/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0509 - accuracy: 0.9840
# Epoch 198/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0255 - accuracy: 1.0000
# Epoch 199/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0204 - accuracy: 1.0000
# Epoch 200/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0529 - accuracy: 0.9840

# %%
def text(txt):
  tokens = nltk.word_tokenize(txt)
  tokens = [lemmatizer.lemmatize(word) for word in tokens]
  return tokens

def word_bag(txt, vocab):
  tokens = text(txt)
  bag_words = [0] * len(vocab)
  for i in tokens:
    for idx, word in enumerate(vocab):
      if word == i:
        bag_words[idx] = 1
  return num.array(bag_words)

def predict_class(txt, vocab, labels):
  bag_words = word_bag(txt, vocab)
  result = model.predict(num.array([bag_words]))[0]
  threshold = 0.2
  y_prob = [[idx, res] for idx, res in enumerate(result) if res > threshold]
  y_prob.sort(key=lambda x: x[1], reverse=True)
  list_y = []
  for i in y_prob:
    list_y.append(labels[i[0]])
  print()
  return list_y

def get_result(result_list, json_intents):
  tag = result_list[0]
  list_intents = json_intents["intents"]
  for i in list_intents:
    if i["tag"] == tag:
      result = random.choice(i["responses"])
      break
  return result

# %%
while True:
  message = input("")
  intents = predict_class(message, words, data_classes)
  res     = get_result(intents, data)
  print(res)
# Out:
# What is your name?
# 1/1 [==============================] - 0s 13ms/step
#
# I am a Deep-Learning chatbot
# Run time of scapegoat tree?
# 1/1 [==============================] - 0s 12ms/step
#
# Scapegoat Trees have amortized run times of O(log n) for insertion and deletion
#  and for a sequence of m insertions  and deletions the overall run time is O(m log m) for all the rebuild operations.
#  A scapegoat tree is a self-balancing binary search tree, invented by Arne Andersson[2] in 1989 and again by Igal Galperin and Ronald L. Rivest in 1993.
# What is an algorithm?
# 1/1 [==============================] - 0s 12ms/step
#
# An algorithm is a list of rules to follow in order to complete a task or solve a problem. E.g. Binary Search Algorithm, Merge Sort Algorithm, Quicksort Algorithm, Kruskal's Algorithm, Floyd Warshall Algorithm and Dijkstra's Algorithm.
# thank you
# 1/1 [==============================] - 0s 14ms/step
#
# Any time!
# Could you tell me the top 10 songs atm?
# 1/1 [==============================] - 0s 14ms/step
#
# You should check out https://top40-charts.com/chart.php?cid=31for top 40 hits.
# I want to check out a news website, any help?
# 1/1 [==============================] - 0s 11ms/step
#
# https://www.bbc.com
# What time is it?
# 1/1 [==============================] - 0s 12ms/step
#
# "2023-02-04 22:24:13.626057"
# Before I leave, could you tell me a joke?
# 1/1 [==============================] - 0s 12ms/step
#
# Did you hear about the mathematician who’s afraid of negative numbers? He’ll stop at nothing to avoid them.
# haha
# 1/1 [==============================] - 0s 14ms/step
#
# Glad I could make you laugh !
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-33249a252f92> in <module>
#       1 while True:
# ----> 2   message = input("")
#       3   intents = predict_class(message, words, data_classes)
#       4   res     = get_result(intents, data)
#       5   print(res)
#
# /usr/local/lib/python3.8/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# /usr/local/lib/python3.8/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
